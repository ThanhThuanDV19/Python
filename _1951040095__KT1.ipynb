# %%
from google.colab import drive
#mount đến thư mục chứa file <"1951040095">_KT1.ipynb

# %%
# Câu 1
print("CHƯƠNG TRÌNH XÁC ĐỊNH SỐ CHẴN LẼ NGUYÊN DƯƠNG")
a=input("Nhap vao so nguyên a: ")
a= int(a)
if (a <= 0):
  print('Vui lòng nhập lại số nguyên dương!')
elif (a % 2) == 0:
   print('Đây là số chẵn')
elif (a % s) != 0:
   print('Đây là số lẻ')
# Out:
# Nhap vao so a: -12
# Vui lòng nhập lại số nguyên dương!

# %%
# Câu 2
print("Bạn hãy nhập vào 1 số nguyên tố duy nhất")
def check_prime_number(n):
  flag = 1;
  if (n < 2):
    flag = 0
    return flag
  for p in range(2,n):
    if n%p == 0:
      flag = 0
      break 
  return flag
n = int(input(">> nhap so tu nhien:"))
check = check_prime_number(n);
if check == 1:
   print(n,"là số nguyên tố")
else:
   print(n,"Xin hãy nhập lại !")
# Out:
# Bạn hãy nhập vào 1 số nguyên tố duy nhất
# >> nhap so tu nhien:13
# 13 là số nguyên tố

# %%
# Câu 3
array=[1,2,3,4,5,6]
def inverse_array(k):
  print(list(reversed(array)))
inverse_array(array)
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
#Câu 4
import math
def fibonacci(n):
    if (n < 0):
        return -1;
    elif (n == 0 or n == 1):
        return n;
    else:
        return fibonacci(n - 1) + fibonacci(n - 2);
def isPrimeNumber(n):
    if (n < 2):
         return False;
    # check so nguyen to khi n >= 2
    squareRoot = int(math.sqrt(n));
    for i in range(2, squareRoot + 1):
        if (n % i == 0):
            return False;
    return True;
 
n = int(input("Nhập số nguyên dương n = "));
print ("Tất cả các số fibonacci nhỏ hơn", n, "và nguyên tố:");
i = 0;
fin = fibonacci(i);
while(fin < n):
    fin = fibonacci(i);
    if (isPrimeNumber(fin)):
        print(fin)
    i = i + 1;
